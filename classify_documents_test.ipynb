# %%
import os
import json
import re
import tempfile
from pdf2image import convert_from_path
import img2pdf
import fitz
from PIL import Image
import io
import pandas as pd
import time
from langchain_upstage import UpstageLayoutAnalysisLoader
from rainbow_html_transformer import HTMLToTextWithMarkdownTables

# %%
def get_pdf_files(folder_path):
    """
    PDF 파일 목록을 가져옴
    folder_path : PDF 파일이 있는 폴더 경로
    반환 : PDF 파일 목록
    """
    return [f for f in os.listdir(folder_path) if f.lower().endswith('.pdf')]

# %%
# def load_json(json_path):
#     with open(json_path, 'r', encoding='utf-8') as f:
#         return json.load(f)

# # JSON 파일 경로
# json_path = "document_class.json"

# # JSON 파일을 딕셔너리로 로드
# json_dict = load_json(json_path)

# # 로드된 딕셔너리 출력 (선택사항)
# print(json_dict)
def load_document_classes(json_path):
    """
    문서 유형별 키워드 Json 파일을 읽어옴
    json_path : 문서 유형별 키워드 Json 파일 경로
    사업방법서 → business_method_document
    상품요약서 → product_summary
    약관 → terms_and_conditions
    반환 : 문서 유형별 키워드 딕셔너리
    """
    with open(json_path, 'r', encoding='utf-8') as f:
        print(f"Loading document classes from {json_path}")
        json_dict = json.load(f)
        print("문서 유형 정의\n",json_dict)
        return json_dict

# %%
# # pdf_path = "./raw_docs/(무)신한 이율보증형 퇴직적립식보험_사업방법서_231018(1)_P8.pdf"
# pdf_path = "./raw_docs/상품요약서_신한대중교통보장보험(무배당)_20240401_P8.pdf"
# # pdf_path = "./raw_docs/SHL0197_신한케어받는암보험(무배당, 갱신형)(3)_P1482.pdf"
# max_pages = 3
# extracted_text = []

# try:
#     doc = fitz.open(pdf_path)
#     print("doc길이", len(doc))
#     # print("doc[0]", doc[0].get_text())
#     # print("doc[1]", doc[1].get_text())
#     # print("doc[2]", doc[2].get_text())
#     for page_num in range(max_pages):
#         page_content = doc[page_num].get_text()
#         extracted_text.append(page_content)
    
#     doc.close()
# except Exception as e:
#     print(f"Error processing {pdf_path}: {e}")

# print(' '.join(extracted_text))
def extract_text_from_pdf(pdf_path, max_pages=3):
    extracted_text = []
    try:
        doc = fitz.open(pdf_path)
        # print(f"{pdf_path} 페이지 수", len(doc))

        for page_num in range(max_pages):
            page_content = doc[page_num].get_text()
            extracted_text.append(page_content)
        
        doc.close()
    except Exception as e:
        print(f"Error processing {pdf_path}: {e}")

    # print(' '.join(extracted_text))

    return ' '.join(extracted_text)

# %%
def classify_document(text_list, document_classes):
    """
    문서 유형 분류
    text : 텍스트
    document_classes : 문서 유형별 키워드
    반환 : 분류된 문서 유형
    """
    for doc_type, keywords in document_classes.items():
        if any(re.search(keyword, text_list, re.IGNORECASE) for keyword in keywords):
            return keywords[0]  # 키워드 리스트의 첫 번째 값 반환
    return "Unknown"

# %%
def extract_text_with_ocr(pdf_path, max_pages=3):
    extracted_text = []
    try:
        # PDF를 이미지로 변환
        images = convert_from_path(pdf_path, first_page=1, last_page=max_pages)
        
        for i, img in enumerate(images):
            with tempfile.NamedTemporaryFile(delete=False, suffix='.png') as temp_file:
                img.save(temp_file, format="PNG")
                temp_file_path = temp_file.name
            
            try:
                loader = UpstageLayoutAnalysisLoader(
                    file_path=temp_file_path,
                    use_ocr=True
                )
                documents = loader.load()
                
                html_transformer = HTMLToTextWithMarkdownTables()
                for doc in documents:
                    # HTML 태그 제거
                    transformed_doc = html_transformer.transform_documents([doc])[0]
                    extracted_text.append(transformed_doc.page_content)
            finally:
                os.unlink(temp_file_path)
    
    except Exception as e:
        print(f"Error processing {pdf_path} with OCR: {e}")
    
    return ' '.join(extracted_text)

# %%
# 사용 예:
# Layout Analysis API의 최대 페이지 제한인 100페이지 이상은 처리 불가
folder_path = "./raw_docs"

json_path = "document_class.json"
document_classes = load_document_classes(json_path)

print("Getting PDF files...")
pdf_files = get_pdf_files(folder_path)
    
print(f"Found {len(pdf_files)} PDF files to process.")
    
results = []

for i, pdf_file in enumerate(pdf_files, 1):
    print(f"Processing file {i} of {len(pdf_files)}: {pdf_file}")
    pdf_path = os.path.join(folder_path, pdf_file)
        
    text = extract_text_from_pdf(pdf_path)
    doc_type = classify_document(text, document_classes)
    
    if doc_type == "Unknown":
        print(f"Document type unknown. Attempting OCR processing for {pdf_file}")
        ocr_text = extract_text_with_ocr(pdf_path)
        doc_type = classify_document(ocr_text, document_classes)
    
    results.append({"file_name": pdf_file, "document_type": doc_type})
    print(f"file_name: {pdf_file} document_type: {doc_type}\n")

# 결과 출력 또는 저장
for result in results:
    print(f"File: {result['file_name']}, Type: {result['document_type']}")
# Out:
# Loading document classes from document_class.json
# 문서 유형 정의
#  {'business_method_document': ['사업방법서', '사업 내용', '비즈니스 방법'], 'product_summary': ['상품요약서', '상품 설명', '요약 정보'], 'terms_and_conditions': ['약관', '계약 조건', '보험 약관']}
# Getting PDF files...
# Found 116 PDF files to process.
# Processing file 1 of 116: SHL0197_신한케어받는암보험(무배당, 갱신형)(3)_P1482.pdf
# Document type unknown. Attempting OCR processing for SHL0197_신한케어받는암보험(무배당, 갱신형)(3)_P1482.pdf
# file_name: SHL0197_신한케어받는암보험(무배당, 갱신형)(3)_P1482.pdf document_type: 약관
#
# Processing file 2 of 116: 상품요약서_신한모으고키우는변액적립보험_240401_P26.pdf
# file_name: 상품요약서_신한모으고키우는변액적립보험_240401_P26.pdf document_type: 상품요약서
#
# Processing file 3 of 116: 사업방법서_신한(간편가입)든든한실속종신보험(무배당, 보증비용부과형)[해약환급금 일부지급형]_20240401_P19.pdf
# file_name: 사업방법서_신한(간편가입)든든한실속종신보험(무배당, 보증비용부과형)[해약환급금 일부지급형]_20240401_P19.pdf document_type: 사업방법서
#
# Processing file 4 of 116: 신한아름다운연금보험(무배당)_상품요약서_240401_v2_P22.pdf
# file_name: 신한아름다운연금보험(무배당)_상품요약서_240401_v2_P22.pdf document_type: 상품요약서
#
# Processing file 5 of 116: DB자산관리_사업방법서_20231018_v1_변경없음 (2)_P21.pdf
# file_name: DB자산관리_사업방법서_20231018_v1_변경없음 (2)_P21.pdf document_type: 사업방법서
#
# Processing file 6 of 116: SHL0068_신한진심을품은대출안심보장보험(무배당)_P254.pdf
# Document type unknown. Attempting OCR processing for SHL0068_신한진심을품은대출안심보장보험(무배당)_P254.pdf
# file_name: SHL0068_신한진심을품은대출안심보장보험(무배당)_P254.pdf document_type: 약관
#
# Processing file 7 of 116: 사업방법서_신한라이프놀라운3대폴립수술보험(무배당)_20230101(변경없음)_P4.pdf
# file_name: 사업방법서_신한라이프놀라운3대폴립수술보험(무배당)_20230101(변경없음)_P4.pdf document_type: 사업방법서
#
# Processing file 8 of 116: SHL0156_신한아름다운연금보험(무배당)_P142.pdf
# Document type unknown. Attempting OCR processing for SHL0156_신한아름다운연금보험(무배당)_P142.pdf
# file_name: SHL0156_신한아름다운연금보험(무배당)_P142.pdf document_type: 약관
#
# Processing file 9 of 116: 015.사업방법서_신한(간편가입)CEO정기보험Ⅱ(무배당,보증비용부과형)_v0.5_20240328(2)_P16.pdf
# file_name: 015.사업방법서_신한(간편가입)CEO정기보험Ⅱ(무배당,보증비용부과형)_v0.5_20240328(2)_P16.pdf document_type: 사업방법서
#
# Processing file 10 of 116: DC자산관리_약관_20240401(1)_P26.pdf
# file_name: DC자산관리_약관_20240401(1)_P26.pdf document_type: 약관
#
# Processing file 11 of 116: 사업방법서_(간편)신한통합건강보장보험원(ONE)(무배당, 해약환급금 미지급형)_20240503_v0.1_P34.pdf
# file_name: 사업방법서_(간편)신한통합건강보장보험원(ONE)(무배당, 해약환급금 미지급형)_20240503_v0.1_P34.pdf document_type: 사업방법서
#
# Processing file 12 of 116: SHL0133_신한큐브종합건강상해보험라이트(무배당, 갱신형)(2)_P1908.pdf
# Document type unknown. Attempting OCR processing for SHL0133_신한큐브종합건강상해보험라이트(무배당, 갱신형)(2)_P1908.pdf
# file_name: SHL0133_신한큐브종합건강상해보험라이트(무배당, 갱신형)(2)_P1908.pdf document_type: 약관
#
# Processing file 13 of 116: 약관_신한포시즌케어보험M(무배당)_20240401_P120.pdf
# Document type unknown. Attempting OCR processing for 약관_신한포시즌케어보험M(무배당)_20240401_P120.pdf
# file_name: 약관_신한포시즌케어보험M(무배당)_20240401_P120.pdf document_type: 약관
#
# Processing file 14 of 116: 상품요약서_신한인터넷2대건강보험(무배당)_20240401(1)_P13.pdf
# Document type unknown. Attempting OCR processing for 상품요약서_신한인터넷2대건강보험(무배당)_20240401(1)_P13.pdf
# file_name: 상품요약서_신한인터넷2대건강보험(무배당)_20240401(1)_P13.pdf document_type: 상품요약서
#
# Processing file 15 of 116: 판매약관_신한스포츠&레저보장보험Plus(무배당)_20240401_P102.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한스포츠&레저보장보험Plus(무배당)_20240401_P102.pdf
# file_name: 판매약관_신한스포츠&레저보장보험Plus(무배당)_20240401_P102.pdf document_type: 약관
#
# Processing file 16 of 116: 사업방법서_신한(간편가입)위너스경영인정기보험(무배당, 해약환급금 일부지급형)_20240401_P21.pdf
# file_name: 사업방법서_신한(간편가입)위너스경영인정기보험(무배당, 해약환급금 일부지급형)_20240401_P21.pdf document_type: 사업방법서
#
# Processing file 17 of 116: 상품요약서_신한포시즌케어보험M(무배당)_20240401_P9.pdf
# file_name: 상품요약서_신한포시즌케어보험M(무배당)_20240401_P9.pdf document_type: 상품요약서
#
# Processing file 18 of 116: 판매약관_신한두개로OK암보험(무배당, 갱신형)_240401(1)_P204.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한두개로OK암보험(무배당, 갱신형)_240401(1)_P204.pdf
# file_name: 판매약관_신한두개로OK암보험(무배당, 갱신형)_240401(1)_P204.pdf document_type: 약관
#
# Processing file 19 of 116: 판매약관_신한인터넷정기보험(무배당)_20240401_P184.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한인터넷정기보험(무배당)_20240401_P184.pdf
# file_name: 판매약관_신한인터넷정기보험(무배당)_20240401_P184.pdf document_type: 약관
#
# Processing file 20 of 116: 상품요약서_신한든든한실속종신보험(무배당, 보증비용부과형)[해약환급금 일부지급형]_20240401_P20.pdf
# file_name: 상품요약서_신한든든한실속종신보험(무배당, 보증비용부과형)[해약환급금 일부지급형]_20240401_P20.pdf document_type: 상품요약서
#
# Processing file 21 of 116: 사업방법서_신한인터넷암보험(무배당, 해약환급금 미지급형)_20240401(1)_P10.pdf
# file_name: 사업방법서_신한인터넷암보험(무배당, 해약환급금 미지급형)_20240401(1)_P10.pdf document_type: 사업방법서
#
# Processing file 22 of 116: 판매약관_신한간편가입큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_수정_P1618.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한간편가입큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_수정_P1618.pdf
# file_name: 판매약관_신한간편가입큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_수정_P1618.pdf document_type: 약관
#
# Processing file 23 of 116: 019.사업방법서_신한참좋은치아보험PlusⅡ(무배당, 갱신형)_v0.1_20240223_P8.pdf
# file_name: 019.사업방법서_신한참좋은치아보험PlusⅡ(무배당, 갱신형)_v0.1_20240223_P8.pdf document_type: 사업방법서
#
# Processing file 24 of 116: SHL0057_신한인터넷암보험(무배당, 해약환급금 미지급형)_P218.pdf
# Document type unknown. Attempting OCR processing for SHL0057_신한인터넷암보험(무배당, 해약환급금 미지급형)_P218.pdf
# file_name: SHL0057_신한인터넷암보험(무배당, 해약환급금 미지급형)_P218.pdf document_type: 약관
#
# Processing file 25 of 116: SHL0035_신한라이프놀라운3대폴립수술보험(무배당)_P132.pdf
# Document type unknown. Attempting OCR processing for SHL0035_신한라이프놀라운3대폴립수술보험(무배당)_P132.pdf
# file_name: SHL0035_신한라이프놀라운3대폴립수술보험(무배당)_P132.pdf document_type: 약관
#
# Processing file 26 of 116: 판매약관_신한VIP참연금저축보험Ⅲ_240401_수정_P108.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한VIP참연금저축보험Ⅲ_240401_수정_P108.pdf
# file_name: 판매약관_신한VIP참연금저축보험Ⅲ_240401_수정_P108.pdf document_type: 약관
#
# Processing file 27 of 116: 044.사업방법서_신한모으고키우는변액적립보험v2.0(무배당)20240401_P27.pdf
# file_name: 044.사업방법서_신한모으고키우는변액적립보험v2.0(무배당)20240401_P27.pdf document_type: 사업방법서
#
# Processing file 28 of 116: 판매약관_신한우리아이교통보장보험M(무배당)_20240401_P136.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한우리아이교통보장보험M(무배당)_20240401_P136.pdf
# file_name: 판매약관_신한우리아이교통보장보험M(무배당)_20240401_P136.pdf document_type: 약관
#
# Processing file 29 of 116: 사업방법서_신한VIP참연금저축보험Ⅲ_20240401_P16.pdf
# file_name: 사업방법서_신한VIP참연금저축보험Ⅲ_20240401_P16.pdf document_type: 사업방법서
#
# Processing file 30 of 116: 038.사업방법서_신한윈윈플러스보험Ⅲ(무배당)_240401_v2_P10.pdf
# file_name: 038.사업방법서_신한윈윈플러스보험Ⅲ(무배당)_240401_v2_P10.pdf document_type: 사업방법서
#
# Processing file 31 of 116: 상품요약서_신한(간편가입)CEO정기보험Ⅱ(무배당, 보증비용부과형)_20240401(1)_P17.pdf
# file_name: 상품요약서_신한(간편가입)CEO정기보험Ⅱ(무배당, 보증비용부과형)_20240401(1)_P17.pdf document_type: 상품요약서
#
# Processing file 32 of 116: IRP자산관리_사업방법서_20230607_변경사항없음 (2)_P25.pdf
# file_name: IRP자산관리_사업방법서_20230607_변경사항없음 (2)_P25.pdf document_type: 사업방법서
#
# Processing file 33 of 116: 판매약관_신한(간편가입)모아더드림종신보험(무배당, 해약환급금 일부지급형)_20240401_P248.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한(간편가입)모아더드림종신보험(무배당, 해약환급금 일부지급형)_20240401_P248.pdf
# file_name: 판매약관_신한(간편가입)모아더드림종신보험(무배당, 해약환급금 일부지급형)_20240401_P248.pdf document_type: 약관
#
# Processing file 34 of 116: 상품요약서_신한우리아이교통보장보험M(무배당)_20240401(1)_P9.pdf
# file_name: 상품요약서_신한우리아이교통보장보험M(무배당)_20240401(1)_P9.pdf document_type: 상품요약서
#
# Processing file 35 of 116: 사업방법서_신한포시즌케어보험M(무배당)_20240401_P4.pdf
# file_name: 사업방법서_신한포시즌케어보험M(무배당)_20240401_P4.pdf document_type: 사업방법서
#
# Processing file 36 of 116: 사업방법서_신한슈퍼SOL연금보험(무배당)_20240401_P16.pdf
# file_name: 사업방법서_신한슈퍼SOL연금보험(무배당)_20240401_P16.pdf document_type: 사업방법서
#
# Processing file 37 of 116: 판매약관_신한모으고키우는변액연금보험(무배당)_20240401_P200.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한모으고키우는변액연금보험(무배당)_20240401_P200.pdf
# file_name: 판매약관_신한모으고키우는변액연금보험(무배당)_20240401_P200.pdf document_type: 약관
#
# Processing file 38 of 116: 사업방법서_신한대중교통보장보험(무배당)_20240401_P5.pdf
# file_name: 사업방법서_신한대중교통보장보험(무배당)_20240401_P5.pdf document_type: 사업방법서
#
# Processing file 39 of 116: 사업방법서_신한진심을품은대출안심보장보험(무배당)_20240401_P5.pdf
# file_name: 사업방법서_신한진심을품은대출안심보장보험(무배당)_20240401_P5.pdf document_type: 사업방법서
#
# Processing file 40 of 116: 약관_신한인터넷어린이보험(무배당)_20240401_P236.pdf
# Document type unknown. Attempting OCR processing for 약관_신한인터넷어린이보험(무배당)_20240401_P236.pdf
# file_name: 약관_신한인터넷어린이보험(무배당)_20240401_P236.pdf document_type: 약관
#
# Processing file 41 of 116: 상품요약서_신한인터넷암보험(무배당_해약환급금 미지급형)_20240401_P16.pdf
# file_name: 상품요약서_신한인터넷암보험(무배당_해약환급금 미지급형)_20240401_P16.pdf document_type: 사업방법서
#
# Processing file 42 of 116: 판매약관_신한올터치종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P1942.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한올터치종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P1942.pdf
# file_name: 판매약관_신한올터치종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P1942.pdf document_type: 약관
#
# Processing file 43 of 116: 상품요약서_신한(간편가입)위너스경영인정기보험(무배당, 해약환급금 일부지급형)_20240401_P22.pdf
# file_name: 상품요약서_신한(간편가입)위너스경영인정기보험(무배당, 해약환급금 일부지급형)_20240401_P22.pdf document_type: 상품요약서
#
# Processing file 44 of 116: 판매약관_신한간편가입큐브종합건강상해보험라이트(무배당, 갱신형)_20240503_vF_P1682.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한간편가입큐브종합건강상해보험라이트(무배당, 갱신형)_20240503_vF_P1682.pdf
# file_name: 판매약관_신한간편가입큐브종합건강상해보험라이트(무배당, 갱신형)_20240503_vF_P1682.pdf document_type: 약관
#
# Processing file 45 of 116: 상품요약서_The안심VIP저축보험(무배당)_20240415_P11.pdf
# file_name: 상품요약서_The안심VIP저축보험(무배당)_20240415_P11.pdf document_type: 상품요약서
#
# Processing file 46 of 116: 사업방법서_신한(간편가입)모아더드림종신보험(무배당, 해약환급금 일부지급형)_20240503_P17.pdf
# file_name: 사업방법서_신한(간편가입)모아더드림종신보험(무배당, 해약환급금 일부지급형)_20240503_P17.pdf document_type: 사업방법서
#
# Processing file 47 of 116: 약관_신한(간편가입)든든한실속종신보험(무배당, 보증비용부과형)[해약환급금 일부지급형]_20240401_P340.pdf
# Document type unknown. Attempting OCR processing for 약관_신한(간편가입)든든한실속종신보험(무배당, 보증비용부과형)[해약환급금 일부지급형]_20240401_P340.pdf
# file_name: 약관_신한(간편가입)든든한실속종신보험(무배당, 보증비용부과형)[해약환급금 일부지급형]_20240401_P340.pdf document_type: 약관
#
# Processing file 48 of 116: SHL0145_신한독감케어건강보험(무배당)_P138.pdf
# Document type unknown. Attempting OCR processing for SHL0145_신한독감케어건강보험(무배당)_P138.pdf
# file_name: SHL0145_신한독감케어건강보험(무배당)_P138.pdf document_type: 약관
#
# Processing file 49 of 116: 사업방법서_신한인터넷어린이보험(무배당)_20240401_P5.pdf
# file_name: 사업방법서_신한인터넷어린이보험(무배당)_20240401_P5.pdf document_type: 사업방법서
#
# Processing file 50 of 116: (무)신한 이율보증형 퇴직적립식보험_약관_231018_v2_P11.pdf
# file_name: (무)신한 이율보증형 퇴직적립식보험_약관_231018_v2_P11.pdf document_type: 약관
#
# Processing file 51 of 116: 상품요약서_신한라이프놀라운3대폴립수술보험(무배당)_20240401_P4.pdf
# file_name: 상품요약서_신한라이프놀라운3대폴립수술보험(무배당)_20240401_P4.pdf document_type: 상품요약서
#
# Processing file 52 of 116: 상품요약서_신한든든한VIP상속종신보험(무배당, 보증비용부과형)[해약환급금 일부지급형]_20240101(1)_P20.pdf
# file_name: 상품요약서_신한든든한VIP상속종신보험(무배당, 보증비용부과형)[해약환급금 일부지급형]_20240101(1)_P20.pdf document_type: 상품요약서
#
# Processing file 53 of 116: 상품요약서_신한VIP참연금저축보험Ⅲ_240401_P18.pdf
# file_name: 상품요약서_신한VIP참연금저축보험Ⅲ_240401_P18.pdf document_type: 상품요약서
#
# Processing file 54 of 116: 상품요약서_신한스포츠&레저보장보험Plus(무배당)_240401_P9.pdf
# file_name: 상품요약서_신한스포츠&레저보장보험Plus(무배당)_240401_P9.pdf document_type: 상품요약서
#
# Processing file 55 of 116: 027.사업방법서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240401_v2_문구수정(1)_P11.pdf
# file_name: 027.사업방법서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240401_v2_문구수정(1)_P11.pdf document_type: 사업방법서
#
# Processing file 56 of 116: 사업방법서_신한The안심VIP저축보험II(무배당)_20240401_보너스_P6.pdf
# file_name: 사업방법서_신한The안심VIP저축보험II(무배당)_20240401_보너스_P6.pdf document_type: 사업방법서
#
# Processing file 57 of 116: (무)신한 이율보증형 퇴직적립식보험_사업방법서_231018(1)_P8.pdf
# file_name: (무)신한 이율보증형 퇴직적립식보험_사업방법서_231018(1)_P8.pdf document_type: 사업방법서
#
# Processing file 58 of 116: 판매약관_신한인터넷2대건강보험(무배당)(고급형)_20240401_P174.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한인터넷2대건강보험(무배당)(고급형)_20240401_P174.pdf
# file_name: 판매약관_신한인터넷2대건강보험(무배당)(고급형)_20240401_P174.pdf document_type: 약관
#
# Processing file 59 of 116: 상품요약서_신한독감케어건강보험(무배당)_20240401_P10.pdf
# file_name: 상품요약서_신한독감케어건강보험(무배당)_20240401_P10.pdf document_type: 상품요약서
#
# Processing file 60 of 116: 상품요약서_(간편)신한통합건강보장보험원(ONE)(무배당_해약환급금미지급형)_20240503_P131.pdf
# file_name: 상품요약서_(간편)신한통합건강보장보험원(ONE)(무배당_해약환급금미지급형)_20240503_P131.pdf document_type: 상품요약서
#
# Processing file 61 of 116: 사업방법서_신한(간편가입)홈닥터의료비보장보험(무배당, 갱신형)_20240401_P14.pdf
# Document type unknown. Attempting OCR processing for 사업방법서_신한(간편가입)홈닥터의료비보장보험(무배당, 갱신형)_20240401_P14.pdf
# file_name: 사업방법서_신한(간편가입)홈닥터의료비보장보험(무배당, 갱신형)_20240401_P14.pdf document_type: 사업방법서
#
# Processing file 62 of 116: 판매약관_신한(간편가입)위너스경영인정기보험(무배당, 해약환급금 일부지급형)_240401_P246.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한(간편가입)위너스경영인정기보험(무배당, 해약환급금 일부지급형)_240401_P246.pdf
# file_name: 판매약관_신한(간편가입)위너스경영인정기보험(무배당, 해약환급금 일부지급형)_240401_P246.pdf document_type: 약관
#
# Processing file 63 of 116: 036.사업방법서_신한우리아이교통보장보험M(무배당)_v0.1_20240223_P6.pdf
# file_name: 036.사업방법서_신한우리아이교통보장보험M(무배당)_v0.1_20240223_P6.pdf document_type: 사업방법서
#
# Processing file 64 of 116: IRP자산관리_약관(기업형)_20240401_P24.pdf
# file_name: IRP자산관리_약관(기업형)_20240401_P24.pdf document_type: 약관
#
# Processing file 65 of 116: DC자산관리_사업방법서_20230607_변경사항없음 (2)_P24.pdf
# file_name: DC자산관리_사업방법서_20230607_변경사항없음 (2)_P24.pdf document_type: 사업방법서
#
# Processing file 66 of 116: 상품요약서_신한간편가입큐브종합건강상해보험라이트(무배당, 갱신형)_20240503_P96.pdf
# file_name: 상품요약서_신한간편가입큐브종합건강상해보험라이트(무배당, 갱신형)_20240503_P96.pdf document_type: 사업방법서
#
# Processing file 67 of 116: 상품요약서_신한모으고키우는변액연금보험(무배당)_20240401(1)_P32.pdf
# file_name: 상품요약서_신한모으고키우는변액연금보험(무배당)_20240401(1)_P32.pdf document_type: 상품요약서
#
# Processing file 68 of 116: 사업방법서_신한간편가입큐브종합건강보장보험(무배당, 해약환급금 미지급형)_20240503_P23.pdf
# file_name: 사업방법서_신한간편가입큐브종합건강보장보험(무배당, 해약환급금 미지급형)_20240503_P23.pdf document_type: 사업방법서
#
# Processing file 69 of 116: 사업방법서_신한인터넷정기보험(무배당)_20240401_P5.pdf
# file_name: 사업방법서_신한인터넷정기보험(무배당)_20240401_P5.pdf document_type: 사업방법서
#
# Processing file 70 of 116: 사업방법서_신한큐브종합건강상해보험라이트(무배당, 갱신형)_240401_P6.pdf
# file_name: 사업방법서_신한큐브종합건강상해보험라이트(무배당, 갱신형)_240401_P6.pdf document_type: 사업방법서
#
# Processing file 71 of 116: SHL0134_신한올타임종합건강상해보험(무배당, 갱신형)(3)_P1908.pdf
# Document type unknown. Attempting OCR processing for SHL0134_신한올타임종합건강상해보험(무배당, 갱신형)(3)_P1908.pdf
# file_name: SHL0134_신한올타임종합건강상해보험(무배당, 갱신형)(3)_P1908.pdf document_type: 약관
#
# Processing file 72 of 116: 사업방법서_신한인터넷2대건강보험(무배당)(실속형)_20240101_P5.pdf
# Document type unknown. Attempting OCR processing for 사업방법서_신한인터넷2대건강보험(무배당)(실속형)_20240101_P5.pdf
# file_name: 사업방법서_신한인터넷2대건강보험(무배당)(실속형)_20240101_P5.pdf document_type: 사업방법서
#
# Processing file 73 of 116: 043.사업방법서_신한모으고키우는변액연금보험(무배당)_v0.2_20240308_P29.pdf
# file_name: 043.사업방법서_신한모으고키우는변액연금보험(무배당)_v0.2_20240308_P29.pdf document_type: 사업방법서
#
# Processing file 74 of 116: 상품요약서_신한참좋은치아보험PlusⅡ(무배당_갱신형)_20240401(1)_P19.pdf
# file_name: 상품요약서_신한참좋은치아보험PlusⅡ(무배당_갱신형)_20240401(1)_P19.pdf document_type: 상품요약서
#
# Processing file 75 of 116: 사업방법서_신한스포츠&레저보장보험Plus(무배당)_20240401_P4.pdf
# file_name: 사업방법서_신한스포츠&레저보장보험Plus(무배당)_20240401_P4.pdf document_type: 사업방법서
#
# Processing file 76 of 116: 상품요약서_신한연금저축보험Premium(무배당)_20240401f_P16.pdf
# file_name: 상품요약서_신한연금저축보험Premium(무배당)_20240401f_P16.pdf document_type: 상품요약서
#
# Processing file 77 of 116: 판매약관_신한연금저축보험Premium(무배당)_20240401_P110.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한연금저축보험Premium(무배당)_20240401_P110.pdf
# file_name: 판매약관_신한연금저축보험Premium(무배당)_20240401_P110.pdf document_type: 약관
#
# Processing file 78 of 116: 판매약관_신한참좋은치아보험PlusⅡ(무배당, 갱신형)_20240401_248.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한참좋은치아보험PlusⅡ(무배당, 갱신형)_20240401_248.pdf
# file_name: 판매약관_신한참좋은치아보험PlusⅡ(무배당, 갱신형)_20240401_248.pdf document_type: 약관
#
# Processing file 79 of 116: SHL0130_신한윈윈플러스보험Ⅲ(무배당)_P588.pdf
# Document type unknown. Attempting OCR processing for SHL0130_신한윈윈플러스보험Ⅲ(무배당)_P588.pdf
# file_name: SHL0130_신한윈윈플러스보험Ⅲ(무배당)_P588.pdf document_type: 약관
#
# Processing file 80 of 116: 판매약관_신한모으고키우는변액적립보험v2.0(무배당)_P174.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한모으고키우는변액적립보험v2.0(무배당)_P174.pdf
# file_name: 판매약관_신한모으고키우는변액적립보험v2.0(무배당)_P174.pdf document_type: 약관
#
# Processing file 81 of 116: 약관_신한(간편가입)든든한VIP상속종신보험(무배당, 보증비용부과형)[해약환급금 일부지급형]_20240401_P340.pdf
# Document type unknown. Attempting OCR processing for 약관_신한(간편가입)든든한VIP상속종신보험(무배당, 보증비용부과형)[해약환급금 일부지급형]_20240401_P340.pdf
# file_name: 약관_신한(간편가입)든든한VIP상속종신보험(무배당, 보증비용부과형)[해약환급금 일부지급형]_20240401_P340.pdf document_type: 약관
#
# Processing file 82 of 116: 상품요약서_신한진심을품은대출안심보장보험(무배당)_240401(1)_P13.pdf
# file_name: 상품요약서_신한진심을품은대출안심보장보험(무배당)_240401(1)_P13.pdf document_type: 상품요약서
#
# Processing file 83 of 116: 사업방법서_신한간편가입큐브종합건강상해보험라이트(무배당, 갱신형)_240503_P20.pdf
# file_name: 사업방법서_신한간편가입큐브종합건강상해보험라이트(무배당, 갱신형)_240503_P20.pdf document_type: 사업방법서
#
# Processing file 84 of 116: 판매약관_신한인터넷2대건강보험(무배당)(실속형)_20240401_P172.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한인터넷2대건강보험(무배당)(실속형)_20240401_P172.pdf
# file_name: 판매약관_신한인터넷2대건강보험(무배당)(실속형)_20240401_P172.pdf document_type: 약관
#
# Processing file 85 of 116: 상품요약서_신한두개로OK암보험(무배당, 갱신형)_240401_P19.pdf
# file_name: 상품요약서_신한두개로OK암보험(무배당, 갱신형)_240401_P19.pdf document_type: 상품요약서
#
# Processing file 86 of 116: 상품요약서_신한인터넷정기보험(무배당)_20240401_P13.pdf
# file_name: 상품요약서_신한인터넷정기보험(무배당)_20240401_P13.pdf document_type: 사업방법서
#
# Processing file 87 of 116: IRP자산관리_약관(개인형)_20230607_변경사항없음 (1)_P30.pdf
# file_name: IRP자산관리_약관(개인형)_20230607_변경사항없음 (1)_P30.pdf document_type: 약관
#
# Processing file 88 of 116: 판매약관_신한(간편가입)홈닥터의료비보장보험(무배당, 갱신형)_20240401_P622.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한(간편가입)홈닥터의료비보장보험(무배당, 갱신형)_20240401_P622.pdf
# file_name: 판매약관_신한(간편가입)홈닥터의료비보장보험(무배당, 갱신형)_20240401_P622.pdf document_type: 약관
#
# Processing file 89 of 116: 상품요약서_신한큐브종합건강상해보험라이트(무배당_갱신형)_240503_P121.pdf
# file_name: 상품요약서_신한큐브종합건강상해보험라이트(무배당_갱신형)_240503_P121.pdf document_type: 상품요약서
#
# Processing file 90 of 116: DB자산관리_약관_20240401_P22.pdf
# file_name: DB자산관리_약관_20240401_P22.pdf document_type: 약관
#
# Processing file 91 of 116: 판매약관_신한간편가입올터치종합건강보장보험(무배당, 해약환급금 미지급형)_240503_수정_P1618.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한간편가입올터치종합건강보장보험(무배당, 해약환급금 미지급형)_240503_수정_P1618.pdf
# file_name: 판매약관_신한간편가입올터치종합건강보장보험(무배당, 해약환급금 미지급형)_240503_수정_P1618.pdf document_type: 약관
#
# Processing file 92 of 116: 사업방법서_신한두개로OK암보험(무배당, 갱신형)_20240401_P12.pdf
# file_name: 사업방법서_신한두개로OK암보험(무배당, 갱신형)_20240401_P12.pdf document_type: 사업방법서
#
# Processing file 93 of 116: 상품요약서_신한케어받는암보험(무배당, 갱신형)_20240503_P55.pdf
# file_name: 상품요약서_신한케어받는암보험(무배당, 갱신형)_20240503_P55.pdf document_type: 상품요약서
#
# Processing file 94 of 116: 판매약관_신한간편가입올타임종합건강상해보험(무배당, 갱신형)_20240503_vF_P1682.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한간편가입올타임종합건강상해보험(무배당, 갱신형)_20240503_vF_P1682.pdf
# file_name: 판매약관_신한간편가입올타임종합건강상해보험(무배당, 갱신형)_20240503_vF_P1682.pdf document_type: 약관
#
# Processing file 95 of 116: 상품요약서_신한슈퍼SOL연금보험(무배당)_20240401_P21.pdf
# file_name: 상품요약서_신한슈퍼SOL연금보험(무배당)_20240401_P21.pdf document_type: 상품요약서
#
# Processing file 96 of 116: SHL0137_신한주니어올터치종합건강상해보험(무배당, 해약환급금 미지급형)_P1010.pdf
# Document type unknown. Attempting OCR processing for SHL0137_신한주니어올터치종합건강상해보험(무배당, 해약환급금 미지급형)_P1010.pdf
# file_name: SHL0137_신한주니어올터치종합건강상해보험(무배당, 해약환급금 미지급형)_P1010.pdf document_type: 약관
#
# Processing file 97 of 116: 상품요약서_신한(간편가입)모아더드림종신보험(무배당_해약환급금 일부지급형)_20240401_P16.pdf
# file_name: 상품요약서_신한(간편가입)모아더드림종신보험(무배당_해약환급금 일부지급형)_20240401_P16.pdf document_type: 상품요약서
#
# Processing file 98 of 116: 상품요약서_신한주니어큐브종합건강상해보험(무배당_해약환급금_미지급형)_20240401_v2_P37.pdf
# file_name: 상품요약서_신한주니어큐브종합건강상해보험(무배당_해약환급금_미지급형)_20240401_v2_P37.pdf document_type: 상품요약서
#
# Processing file 99 of 116: 상품요약서_신한인터넷어린이보험(무배당)_20240401_P12.pdf
# file_name: 상품요약서_신한인터넷어린이보험(무배당)_20240401_P12.pdf document_type: 상품요약서
#
# Processing file 100 of 116: SHL0165_The안심VIP저축보험Ⅱ(무배당)_P116.pdf
# Document type unknown. Attempting OCR processing for SHL0165_The안심VIP저축보험Ⅱ(무배당)_P116.pdf
# file_name: SHL0165_The안심VIP저축보험Ⅱ(무배당)_P116.pdf document_type: 약관
#
# Processing file 101 of 116: 상품요약서_신한(간편가입)홈닥터의료비보장보험(무배당_갱신형)_20240401_v1_P34.pdf
# Document type unknown. Attempting OCR processing for 상품요약서_신한(간편가입)홈닥터의료비보장보험(무배당_갱신형)_20240401_v1_P34.pdf
# file_name: 상품요약서_신한(간편가입)홈닥터의료비보장보험(무배당_갱신형)_20240401_v1_P34.pdf document_type: 상품요약서
#
# Processing file 102 of 116: 사업방법서_신한연금저축보험Premium(무배당)_20240401_P15.pdf
# file_name: 사업방법서_신한연금저축보험Premium(무배당)_20240401_P15.pdf document_type: 사업방법서
#
# Processing file 103 of 116: SHL0140_신한주니어큐브종합건강상해보험(무배당, 해약환급금 미지급형)_P1010.pdf
# Document type unknown. Attempting OCR processing for SHL0140_신한주니어큐브종합건강상해보험(무배당, 해약환급금 미지급형)_P1010.pdf
# file_name: SHL0140_신한주니어큐브종합건강상해보험(무배당, 해약환급금 미지급형)_P1010.pdf document_type: 약관
#
# Processing file 104 of 116: 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109.pdf
# file_name: 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109.pdf document_type: 상품요약서
#
# Processing file 105 of 116: 사업방법서_신한아름다운연금보험(무배당)_20240401_v3_P16.pdf
# file_name: 사업방법서_신한아름다운연금보험(무배당)_20240401_v3_P16.pdf document_type: 사업방법서
#
# Processing file 106 of 116: 약관_(간편)신한통합건강보장보험 원(ONE)(무배당, 해약환급금 미지급형)_20240503_P3278.pdf
# Document type unknown. Attempting OCR processing for 약관_(간편)신한통합건강보장보험 원(ONE)(무배당, 해약환급금 미지급형)_20240503_P3278.pdf
# file_name: 약관_(간편)신한통합건강보장보험 원(ONE)(무배당, 해약환급금 미지급형)_20240503_P3278.pdf document_type: 약관
#
# Processing file 107 of 116: 사업방법서_신한독감케어건강보험(무배당)_20230703_P4.pdf
# Document type unknown. Attempting OCR processing for 사업방법서_신한독감케어건강보험(무배당)_20230703_P4.pdf
# file_name: 사업방법서_신한독감케어건강보험(무배당)_20230703_P4.pdf document_type: 사업방법서
#
# Processing file 108 of 116: 사업방법서_신한케어받는암보험(무배당, 갱신형)_20240401_P6.pdf
# file_name: 사업방법서_신한케어받는암보험(무배당, 갱신형)_20240401_P6.pdf document_type: 사업방법서
#
# Processing file 109 of 116: 034_사업방법서_신한주니어큐브종합건강상해보험(무배당, 해약환급금 미지급형)_20240401_P15.pdf
# file_name: 034_사업방법서_신한주니어큐브종합건강상해보험(무배당, 해약환급금 미지급형)_20240401_P15.pdf document_type: 사업방법서
#
# Processing file 110 of 116: 판매약관_신한인터넷정기보험(무배당)(전환용)_20240401_P154.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한인터넷정기보험(무배당)(전환용)_20240401_P154.pdf
# file_name: 판매약관_신한인터넷정기보험(무배당)(전환용)_20240401_P154.pdf document_type: 약관
#
# Processing file 111 of 116: 상품요약서_신한대중교통보장보험(무배당)_20240401_P8.pdf
# file_name: 상품요약서_신한대중교통보장보험(무배당)_20240401_P8.pdf document_type: 상품요약서
#
# Processing file 112 of 116: 판매약관_신한(간편가입)CEO정기보험Ⅱ(무배당, 보증비용부과형)_20240401_P216.pdf
# Document type unknown. Attempting OCR processing for 판매약관_신한(간편가입)CEO정기보험Ⅱ(무배당, 보증비용부과형)_20240401_P216.pdf
# file_name: 판매약관_신한(간편가입)CEO정기보험Ⅱ(무배당, 보증비용부과형)_20240401_P216.pdf document_type: 약관
#
# Processing file 113 of 116: 약관_신한슈퍼SOL연금보험(무배당)_20240401_P144.pdf
# Document type unknown. Attempting OCR processing for 약관_신한슈퍼SOL연금보험(무배당)_20240401_P144.pdf
# file_name: 약관_신한슈퍼SOL연금보험(무배당)_20240401_P144.pdf document_type: 약관
#
# Processing file 114 of 116: SHL0086_신한대중교통보장보험(무배당)_디지털(보험금 대리청구 특약 부가)_P132.pdf
# Document type unknown. Attempting OCR processing for SHL0086_신한대중교통보장보험(무배당)_디지털(보험금 대리청구 특약 부가)_P132.pdf
# file_name: SHL0086_신한대중교통보장보험(무배당)_디지털(보험금 대리청구 특약 부가)_P132.pdf document_type: 약관
#
# Processing file 115 of 116: 상품요약서_신한간편가입큐브종합건강보장보험(무배당, 해약환급금 미지급형)_20240503_