# %%
import re
import os
import click
import pdfplumber
import tempfile
from pdf2image import convert_from_path
import img2pdf
from PIL import Image
import io
import pandas as pd
from collections import defaultdict
from langchain_upstage import UpstageLayoutAnalysisLoader
from langchain.schema import Document
from rainbow_html_transformer import HTMLToTextWithMarkdownTables

# %%
def extract_text_with_page_info(pdf_path):
    """PDF에서 페이지 정보를 포함한 텍스트를 추출합니다."""
    text_with_page_info = []
    with pdfplumber.open(pdf_path) as pdf:
        for page_num, page in enumerate(pdf.pages, start=1):
            text = page.extract_text()
            text_with_page_info.append((page_num, text))
    return text_with_page_info

# %%
# def extract_text_with_page_info(pdf_path):
#     """UpstageLayoutAnalysisLoader를 사용하여 PDF에서 페이지 정보를 포함한 텍스트를 추출합니다."""
#     loader = UpstageLayoutAnalysisLoader(pdf_path, split="page")
#     documents = loader.load()
    
#     text_with_page_info = []
#     # HTML 문서를 텍스트로 변환하는 변환기 생성
#     html_transformer = HTMLToTextWithMarkdownTables()
        
#     for doc in documents:
#         transformed_doc = html_transformer.transform_documents([doc])[0]
#         page_number = transformed_doc.metadata['page']  # 여기서 페이지 번호를 추출합니다
#         text_with_page_info.append((page_number, transformed_doc.page_content))
#         print(f"Processing page {page_number}")  # 디버깅을 위한 출력

    
#     return text_with_page_info
def convert_pdf_to_pdf(input_path, output_path):
    """PDF를 이미지로 변환한 후 다시 PDF로 변환합니다."""
    with tempfile.TemporaryDirectory() as temp_dir:
        # PDF를 이미지로 변환
        images = convert_from_path(input_path)
        
        # 이미지를 바이트 스트림으로 변환
        image_bytes = []
        for img in images:
            byte_arr = io.BytesIO()
            img.save(byte_arr, format='PNG')
            image_bytes.append(byte_arr.getvalue())
        
        # 이미지를 PDF로 변환
        with open(output_path, "wb") as f:
            f.write(img2pdf.convert(image_bytes))

def extract_text_with_page_info(pdf_path):
    """UpstageLayoutAnalysisLoader를 사용하여 PDF에서 페이지 정보를 포함한 텍스트를 추출하고 저장합니다."""
    try:
        loader = UpstageLayoutAnalysisLoader(
            pdf_path,
            split="page",
            use_ocr=True,  # OCR 활성화
            # ocr_languages=["eng", "kor"],  # OCR 언어 설정 (영어와 한국어)
            exclude=["annotations"]
        )
        documents = loader.load()
    except KeyError as e:
        print(f"Error processing {pdf_path}: {e}")
        print("Attempting to convert and reprocess the PDF...")
        
        # 임시 파일 생성
        with tempfile.NamedTemporaryFile(suffix=".pdf", delete=False) as temp_file:
            temp_pdf_path = temp_file.name
        
        # PDF 변환
        convert_pdf_to_pdf(pdf_path, temp_pdf_path)
        
        # 변환된 PDF로 다시 시도
        try:
            loader = UpstageLayoutAnalysisLoader(
                        temp_pdf_path,
                        split="page",
                        use_ocr=True,  # OCR 활성화
                        # ocr_languages=["eng", "kor"],  # OCR 언어 설정 (영어와 한국어)
                        exclude=["annotations"]
                    )
            documents = loader.load()
        except Exception as e:
            print(f"Error processing converted PDF: {e}")
            os.unlink(temp_pdf_path)  # 임시 파일 삭제
            return []  # 빈 리스트 반환 또는 다른 적절한 처리
        
        os.unlink(temp_pdf_path)  # 임시 파일 삭제
    
    text_with_page_info = []
    html_transformer = HTMLToTextWithMarkdownTables()
    
    # PDF 파일 이름 추출 (확장자 제외)
    pdf_name = os.path.splitext(os.path.basename(pdf_path))[0]
    
    # 저장할 디렉토리 생성
    output_dir = "./processed_txt"
    os.makedirs(output_dir, exist_ok=True)
    
    for doc in documents:
        transformed_doc = html_transformer.transform_documents([doc])[0]
        page_number = transformed_doc.metadata['page']
        text_content = transformed_doc.page_content
        
        # 텍스트 파일로 저장
        output_html_filename = f"{pdf_name}_Page_{page_number}.html"
        output_html_path = os.path.join(output_dir, output_html_filename)
        
        with open(output_html_path, 'w', encoding='utf-8') as file:
            file.write(doc.page_content)

        # 텍스트 파일로 저장
        output_filename = f"{pdf_name}_Page_{page_number}.txt"
        output_path = os.path.join(output_dir, output_filename)
        
        with open(output_path, 'w', encoding='utf-8') as file:
            file.write(text_content)
        
        text_with_page_info.append((page_number, text_content))
        print(f"Processed and saved page {page_number} to {output_filename}")

    return text_with_page_info

# %%
def split_text_into_sections_with_metadata(text_with_page_info):
    """텍스트를 페이지 및 섹션, 서브 섹션 메타데이터와 함께 분리합니다."""
    sections = []
    
    section_pattern = re.compile(r'^\d+\.\s[^\n]+', re.MULTILINE)
    subsection_pattern = re.compile(r'^\d+\.\d+\.\s[^\n]+', re.MULTILINE)
    
    current_section = None
    current_subsection = None

    for page_num, text in text_with_page_info:
        for line in text.splitlines():
            section_match = section_pattern.match(line)
            subsection_match = subsection_pattern.match(line)

            if section_match:
                current_section = section_match.group().strip()
                current_subsection = None  # 섹션이 변경되면 서브섹션 초기화
                sections.append({
                    'Page': page_num,
                    'Section': current_section,
                    'Subsection': '',
                    'Content': ''
                })
            elif subsection_match and current_section:
                current_subsection = subsection_match.group().strip()
                sections.append({
                    'Page': page_num,
                    'Section': current_section,
                    'Subsection': current_subsection,
                    'Content': ''
                })
            elif current_section:
                if current_subsection:
                    sections[-1]['Content'] += " " + line.strip()
                else:
                    sections[-1]['Content'] += " " + line.strip()

    return sections

# %%
def sections_to_dataframe_with_metadata(sections, file_name):
    """섹션과 메타데이터를 포함한 데이터프레임으로 변환합니다."""
    data = []
    for section_data in sections:
        data.append([
            file_name,
            section_data['Page'],
            section_data['Section'],
            section_data['Subsection'],
            section_data['Content'].strip()
        ])
    
    df = pd.DataFrame(data, columns=["File", "Page", "Section", "Subsection", "Content"])
    return df

def save_sections_to_excel(df, output_path):
    """데이터프레임을 엑셀 파일로 저장합니다."""
    df.to_excel(output_path, index=False)

# %%
def process_pdfs_in_directory(pdf_directory, output_excel_path):
    """디렉토리 내 모든 PDF 파일을 처리하여 결과를 엑셀 파일로 저장합니다."""
    all_dataframes = []
    for file_name in os.listdir(pdf_directory):
        if file_name.endswith(".pdf"):
            pdf_path = os.path.join(pdf_directory, file_name)
            text_with_page_info = extract_text_with_page_info(pdf_path)
            sections = split_text_into_sections_with_metadata(text_with_page_info)
            df = sections_to_dataframe_with_metadata(sections, file_name)
            all_dataframes.append(df)
    
    # 모든 데이터프레임을 하나로 합치기
    final_df = pd.concat(all_dataframes, ignore_index=True)
    save_sections_to_excel(final_df, output_excel_path)

# %%
# 사용 예시
pdf_directory = "./raw_docs"  # PDF 파일들이 저장된 디렉토리 경로
output_excel_path = "./output_sections_with_metadata.xlsx"  # 저장할 엑셀 파일 경로

process_pdfs_in_directory(pdf_directory, output_excel_path)
# Out:
# Processed and saved page 1 to 027.사업방법서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240401_v2_문구수정(1)_P11_Page_1.txt
# Processed and saved page 2 to 027.사업방법서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240401_v2_문구수정(1)_P11_Page_2.txt
# Processed and saved page 3 to 027.사업방법서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240401_v2_문구수정(1)_P11_Page_3.txt
# Processed and saved page 4 to 027.사업방법서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240401_v2_문구수정(1)_P11_Page_4.txt
# Processed and saved page 5 to 027.사업방법서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240401_v2_문구수정(1)_P11_Page_5.txt
# Processed and saved page 6 to 027.사업방법서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240401_v2_문구수정(1)_P11_Page_6.txt
# Processed and saved page 7 to 027.사업방법서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240401_v2_문구수정(1)_P11_Page_7.txt
# Processed and saved page 8 to 027.사업방법서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240401_v2_문구수정(1)_P11_Page_8.txt
# Processed and saved page 9 to 027.사업방법서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240401_v2_문구수정(1)_P11_Page_9.txt
# Processed and saved page 10 to 027.사업방법서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240401_v2_문구수정(1)_P11_Page_10.txt
# Processed and saved page 11 to 027.사업방법서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240401_v2_문구수정(1)_P11_Page_11.txt
# /home/samuel/Dev/RAG/AutoRAG-tutorial-ko/rainbow_html_transformer.py:19: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   table.replace_with(BeautifulSoup(markdown_table, 'html.parser'))
# Error processing ./raw_docs/DB자산관리_약관_20240401_P22.pdf: '/S'
# Attempting to convert and reprocess the PDF...
# Processed and saved page 1 to DB자산관리_약관_20240401_P22_Page_1.txt
# Processed and saved page 2 to DB자산관리_약관_20240401_P22_Page_2.txt
# Processed and saved page 3 to DB자산관리_약관_20240401_P22_Page_3.txt
# Processed and saved page 4 to DB자산관리_약관_20240401_P22_Page_4.txt
# Processed and saved page 5 to DB자산관리_약관_20240401_P22_Page_5.txt
# Processed and saved page 6 to DB자산관리_약관_20240401_P22_Page_6.txt
# Processed and saved page 7 to DB자산관리_약관_20240401_P22_Page_7.txt
# Processed and saved page 8 to DB자산관리_약관_20240401_P22_Page_8.txt
# Processed and saved page 9 to DB자산관리_약관_20240401_P22_Page_9.txt
# Processed and saved page 10 to DB자산관리_약관_20240401_P22_Page_10.txt
# Processed and saved page 11 to DB자산관리_약관_20240401_P22_Page_11.txt
# Processed and saved page 12 to DB자산관리_약관_20240401_P22_Page_12.txt
# Processed and saved page 13 to DB자산관리_약관_20240401_P22_Page_13.txt
# Processed and saved page 14 to DB자산관리_약관_20240401_P22_Page_14.txt
# Processed and saved page 15 to DB자산관리_약관_20240401_P22_Page_15.txt
# Processed and saved page 16 to DB자산관리_약관_20240401_P22_Page_16.txt
# Processed and saved page 17 to DB자산관리_약관_20240401_P22_Page_17.txt
# Processed and saved page 18 to DB자산관리_약관_20240401_P22_Page_18.txt
# Processed and saved page 19 to DB자산관리_약관_20240401_P22_Page_19.txt
# Processed and saved page 20 to DB자산관리_약관_20240401_P22_Page_20.txt
# Processed and saved page 21 to DB자산관리_약관_20240401_P22_Page_21.txt
# Processed and saved page 22 to DB자산관리_약관_20240401_P22_Page_22.txt
# Processed and saved page 1 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_1.txt
# Processed and saved page 2 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_2.txt
# Processed and saved page 3 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_3.txt
# Processed and saved page 4 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_4.txt
# Processed and saved page 5 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_5.txt
# Processed and saved page 6 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_6.txt
# Processed and saved page 7 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_7.txt
# Processed and saved page 8 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_8.txt
# Processed and saved page 9 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_9.txt
# Processed and saved page 10 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_10.txt
# Processed and saved page 11 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_11.txt
# Processed and saved page 12 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_12.txt
# Processed and saved page 13 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_13.txt
# Processed and saved page 14 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_14.txt
# Processed and saved page 15 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_15.txt
# Processed and saved page 16 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_16.txt
# Processed and saved page 17 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_17.txt
# Processed and saved page 18 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_18.txt
# Processed and saved page 19 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_19.txt
# Processed and saved page 20 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_20.txt
# Processed and saved page 21 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_21.txt
# Processed and saved page 22 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_22.txt
# Processed and saved page 23 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_23.txt
# Processed and saved page 24 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_24.txt
# Processed and saved page 25 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_25.txt
# Processed and saved page 26 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_26.txt
# Processed and saved page 27 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_27.txt
# Processed and saved page 28 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_28.txt
# Processed and saved page 29 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_29.txt
# Processed and saved page 30 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_30.txt
# Processed and saved page 31 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_31.txt
# Processed and saved page 32 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_32.txt
# Processed and saved page 33 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_33.txt
# Processed and saved page 34 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_34.txt
# Processed and saved page 35 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_35.txt
# Processed and saved page 36 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_36.txt
# Processed and saved page 37 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_37.txt
# Processed and saved page 38 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_38.txt
# Processed and saved page 39 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_39.txt
# Processed and saved page 40 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_40.txt
# Processed and saved page 41 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_41.txt
# Processed and saved page 42 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_42.txt
# Processed and saved page 43 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_43.txt
# Processed and saved page 44 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_44.txt
# Processed and saved page 45 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_45.txt
# Processed and saved page 46 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_46.txt
# Processed and saved page 47 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_47.txt
# Processed and saved page 48 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_48.txt
# Processed and saved page 49 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_49.txt
# Processed and saved page 50 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_50.txt
# Processed and saved page 51 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_51.txt
# Processed and saved page 52 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_52.txt
# Processed and saved page 53 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_53.txt
# Processed and saved page 54 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_54.txt
# Processed and saved page 55 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_55.txt
# Processed and saved page 56 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_56.txt
# Processed and saved page 57 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_57.txt
# Processed and saved page 58 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_58.txt
# Processed and saved page 59 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_59.txt
# Processed and saved page 60 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_60.txt
# Processed and saved page 61 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_61.txt
# Processed and saved page 62 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_62.txt
# Processed and saved page 63 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_63.txt
# Processed and saved page 64 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_64.txt
# Processed and saved page 65 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_65.txt
# Processed and saved page 66 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_66.txt
# Processed and saved page 67 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_67.txt
# Processed and saved page 68 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_68.txt
# Processed and saved page 69 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_69.txt
# Processed and saved page 70 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_70.txt
# Processed and saved page 71 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_71.txt
# Processed and saved page 72 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_72.txt
# Processed and saved page 73 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_73.txt
# Processed and saved page 74 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_74.txt
# Processed and saved page 75 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_75.txt
# Processed and saved page 76 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_76.txt
# Processed and saved page 77 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_77.txt
# Processed and saved page 78 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_78.txt
# Processed and saved page 79 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_79.txt
# Processed and saved page 80 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_80.txt
# Processed and saved page 81 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_81.txt
# Processed and saved page 82 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_82.txt
# Processed and saved page 83 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_83.txt
# Processed and saved page 84 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_84.txt
# Processed and saved page 85 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_85.txt
# Processed and saved page 86 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_86.txt
# Processed and saved page 87 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_87.txt
# Processed and saved page 88 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_88.txt
# Processed and saved page 89 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_89.txt
# Processed and saved page 90 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_90.txt
# Processed and saved page 91 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_91.txt
# Processed and saved page 92 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_92.txt
# Processed and saved page 93 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_93.txt
# Processed and saved page 94 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_94.txt
# Processed and saved page 95 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_95.txt
# Processed and saved page 96 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_96.txt
# Processed and saved page 97 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_97.txt
# Processed and saved page 98 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_98.txt
# Processed and saved page 99 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_99.txt
# Processed and saved page 100 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_100.txt
# Processed and saved page 101 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_101.txt
# Processed and saved page 102 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_102.txt
# Processed and saved page 103 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_103.txt
# Processed and saved page 104 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_104.txt
# Processed and saved page 105 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_105.txt
# Processed and saved page 106 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_106.txt
# Processed and saved page 107 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_107.txt
# Processed and saved page 108 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_108.txt
# Processed and saved page 109 to 상품요약서_신한큐브종합건강보장보험(무배당, 해약환급금 미지급형)_240503_v1_P109_Page_109.txt
