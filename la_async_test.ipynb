# %%
import os
import requests
import time
import fitz
import tempfile
from pathlib import Path
# API 키를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API 키 정보 로드
load_dotenv()

# 환경변수에서 API 키 가져오기
API_KEY = os.getenv("UPSTAGE_API_KEY")

# %%
# PDF 분할 함수
def split_pdf(input_path, max_pages=50):
    doc = fitz.open(input_path)
    total_pages = len(doc)
    print("문서의 총 페이지 수:", total_pages)
    for start in range(0, total_pages, max_pages):
        end = min(start + max_pages, total_pages)
        with tempfile.NamedTemporaryFile(delete=False, suffix='.pdf') as temp_file:
            temp_doc = fitz.open()
            temp_doc.insert_pdf(doc, from_page=start, to_page=end-1)
            temp_doc.save(temp_file.name)
            temp_doc.close()
            yield temp_file.name

# %%
pdf_path = "./raw_docs/상품3/판매약관_신한(간편가입)든든한실속종신보험(무배당, 보증비용부과형)[해약환급금 미지급형]_240903.pdf"

url = "https://api.upstage.ai/v1/document-ai/async/layout-analysis"
headers = {
    "Authorization": f"Bearer {API_KEY}"
}

all_extracted_text = []

# 전체 페이지 수 확인
total_pages = len(fitz.open(pdf_path))
print(f"총 페이지 수: {total_pages}")

processed_pages = 0
total_start_time = time.time()
total_page_processing_time = 0

for i, split_pdf_path in enumerate(split_pdf(pdf_path), 1):
    split_start_time = time.time()
    print(f"\n처리 중인 분할 PDF {i}")
    
    with open(split_pdf_path, "rb") as file:
        files = {"document": file}
        data = {"ocr": "true"}
        
        print("API 요청 제출 중...")
        response = requests.post(url, headers=headers, files=files, data=data)
        response.raise_for_status()
        request_id = response.json()["request_id"]
    
    print("결과 대기 중...")
    status_url = f"https://api.upstage.ai/v1/document-ai/requests/{request_id}"
    while True:
        response = requests.get(status_url, headers=headers)
        response.raise_for_status()
        status_data = response.json()
            
        if status_data["status"] == "completed":
            break
        elif status_data["status"] == "failed":
            raise Exception(f"처리 실패: {status_data['failure_message']}")
            
        print(".", end="", flush=True)
        time.sleep(10)
    
    print("\n결과 다운로드 및 처리 중...")
    extracted_text = []
    for batch in status_data["batches"]:
        download_url = batch["download_url"]
        batch_response = requests.get(download_url)
        batch_response.raise_for_status()
        batch_data = batch_response.json()
        
        if "elements" in batch_data:
            pages = {}
            for element in batch_data["elements"]:
                page_num = element.get("page", 0)
                if page_num not in pages:
                    pages[page_num] = []
                pages[page_num].append(element)
            
            for page_num, elements in sorted(pages.items()):
                page_start_time = time.time()
                processed_pages += 1
                page_content = "\n".join([element["text"] for element in elements if "text" in element])
                extracted_text.append(page_content)
                extracted_text.append(f"\n\n--- End of Page {page_num} ---\n\n")
                page_end_time = time.time()
                page_duration = page_end_time - page_start_time
                total_page_processing_time += page_duration
                print(f"페이지 {processed_pages}/{total_pages} 처리 완료 (소요 시간: {page_duration:.2f}초)")
        else:
            print("예상치 못한 배치 데이터 구조. 'elements' 키를 찾을 수 없습니다.")
            continue
                
    all_extracted_text.extend(extracted_text)

    os.unlink(split_pdf_path)
    split_end_time = time.time()
    split_duration = split_end_time - split_start_time
    print(f"분할 PDF {i} 처리 완료 (소요 시간: {split_duration:.2f}초)")

total_end_time = time.time()
total_duration = total_end_time - total_start_time
avg_page_duration = total_duration / total_pages

print(f"\n텍스트 추출 완료")
print(f"총 소요 시간: {total_duration:.2f}초")
print(f"평균 페이지 처리 시간: {avg_page_duration:.2f}초")

# 추출된 텍스트를 파일로 저장
input_dir = Path(pdf_path).parent
output_file = input_dir / f"{Path(pdf_path).stem}_extracted.txt"
with open(output_file, "w", encoding="utf-8") as f:
    f.write("".join(all_extracted_text))

print(f"\n추출된 텍스트가 다음 위치에 저장되었습니다: {output_file}")
print("추출된 텍스트 (처음 500자):")
print("".join(all_extracted_text)[:500] + "...")
# Out:
# 총 페이지 수: 342
# 문서의 총 페이지 수: 342
#
# 처리 중인 분할 PDF 1
# API 요청 제출 중...
# 결과 대기 중...
# ..
# 결과 다운로드 및 처리 중...
# 페이지 1/342 처리 완료 (소요 시간: 0.00초)
# 페이지 2/342 처리 완료 (소요 시간: 0.00초)
# 페이지 3/342 처리 완료 (소요 시간: 0.00초)
# 페이지 4/342 처리 완료 (소요 시간: 0.00초)
# 페이지 5/342 처리 완료 (소요 시간: 0.00초)
# 페이지 6/342 처리 완료 (소요 시간: 0.00초)
# 페이지 7/342 처리 완료 (소요 시간: 0.00초)
# 페이지 8/342 처리 완료 (소요 시간: 0.00초)
# 페이지 9/342 처리 완료 (소요 시간: 0.00초)
# 페이지 10/342 처리 완료 (소요 시간: 0.00초)
# 페이지 11/342 처리 완료 (소요 시간: 0.00초)
# 페이지 12/342 처리 완료 (소요 시간: 0.00초)
# 페이지 13/342 처리 완료 (소요 시간: 0.00초)
# 페이지 14/342 처리 완료 (소요 시간: 0.00초)
# 페이지 15/342 처리 완료 (소요 시간: 0.00초)
# 페이지 16/342 처리 완료 (소요 시간: 0.00초)
# 페이지 17/342 처리 완료 (소요 시간: 0.00초)
# 페이지 18/342 처리 완료 (소요 시간: 0.00초)
# 페이지 19/342 처리 완료 (소요 시간: 0.00초)
# 페이지 20/342 처리 완료 (소요 시간: 0.00초)
# 페이지 21/342 처리 완료 (소요 시간: 0.00초)
# 페이지 22/342 처리 완료 (소요 시간: 0.00초)
# 페이지 23/342 처리 완료 (소요 시간: 0.00초)
# 페이지 24/342 처리 완료 (소요 시간: 0.00초)
# 페이지 25/342 처리 완료 (소요 시간: 0.00초)
# 페이지 26/342 처리 완료 (소요 시간: 0.00초)
# 페이지 27/342 처리 완료 (소요 시간: 0.00초)
# 페이지 28/342 처리 완료 (소요 시간: 0.00초)
# 페이지 29/342 처리 완료 (소요 시간: 0.00초)
# 페이지 30/342 처리 완료 (소요 시간: 0.00초)
# 페이지 31/342 처리 완료 (소요 시간: 0.00초)
# 페이지 32/342 처리 완료 (소요 시간: 0.00초)
# 페이지 33/342 처리 완료 (소요 시간: 0.00초)
# 페이지 34/342 처리 완료 (소요 시간: 0.00초)
# 페이지 35/342 처리 완료 (소요 시간: 0.00초)
# 페이지 36/342 처리 완료 (소요 시간: 0.00초)
# 페이지 37/342 처리 완료 (소요 시간: 0.00초)
# 페이지 38/342 처리 완료 (소요 시간: 0.00초)
# 페이지 39/342 처리 완료 (소요 시간: 0.00초)
# 페이지 40/342 처리 완료 (소요 시간: 0.00초)
# 페이지 41/342 처리 완료 (소요 시간: 0.00초)
# 페이지 42/342 처리 완료 (소요 시간: 0.00초)
# 페이지 43/342 처리 완료 (소요 시간: 0.00초)
# 페이지 44/342 처리 완료 (소요 시간: 0.00초)
# 페이지 45/342 처리 완료 (소요 시간: 0.00초)
# 페이지 46/342 처리 완료 (소요 시간: 0.00초)
# 페이지 47/342 처리 완료 (소요 시간: 0.00초)
# 페이지 48/342 처리 완료 (소요 시간: 0.00초)
# 페이지 49/342 처리 완료 (소요 시간: 0.00초)
# 페이지 50/342 처리 완료 (소요 시간: 0.00초)
# 분할 PDF 1 처리 완료 (소요 시간: 21.16초)
#
# 처리 중인 분할 PDF 2
# API 요청 제출 중...
# 결과 대기 중...
# ..
# 결과 다운로드 및 처리 중...
# 페이지 51/342 처리 완료 (소요 시간: 0.00초)
# 페이지 52/342 처리 완료 (소요 시간: 0.00초)
# 페이지 53/342 처리 완료 (소요 시간: 0.00초)
# 페이지 54/342 처리 완료 (소요 시간: 0.00초)
# 페이지 55/342 처리 완료 (소요 시간: 0.00초)
# 페이지 56/342 처리 완료 (소요 시간: 0.00초)
# 페이지 57/342 처리 완료 (소요 시간: 0.00초)
# 페이지 58/342 처리 완료 (소요 시간: 0.00초)
# 페이지 59/342 처리 완료 (소요 시간: 0.00초)
# 페이지 60/342 처리 완료 (소요 시간: 0.00초)
# 페이지 61/342 처리 완료 (소요 시간: 0.00초)
# 페이지 62/342 처리 완료 (소요 시간: 0.00초)
# 페이지 63/342 처리 완료 (소요 시간: 0.00초)
# 페이지 64/342 처리 완료 (소요 시간: 0.00초)
# 페이지 65/342 처리 완료 (소요 시간: 0.00초)
# 페이지 66/342 처리 완료 (소요 시간: 0.00초)
# 페이지 67/342 처리 완료 (소요 시간: 0.00초)
# 페이지 68/342 처리 완료 (소요 시간: 0.00초)
# 페이지 69/342 처리 완료 (소요 시간: 0.00초)
# 페이지 70/342 처리 완료 (소요 시간: 0.00초)
# 페이지 71/342 처리 완료 (소요 시간: 0.00초)
# 페이지 72/342 처리 완료 (소요 시간: 0.00초)
# 페이지 73/342 처리 완료 (소요 시간: 0.00초)
# 페이지 74/342 처리 완료 (소요 시간: 0.00초)
# 페이지 75/342 처리 완료 (소요 시간: 0.00초)
# 페이지 76/342 처리 완료 (소요 시간: 0.00초)
# 페이지 77/342 처리 완료 (소요 시간: 0.00초)
# 페이지 78/342 처리 완료 (소요 시간: 0.00초)
# 페이지 79/342 처리 완료 (소요 시간: 0.00초)
# 페이지 80/342 처리 완료 (소요 시간: 0.00초)
# 페이지 81/342 처리 완료 (소요 시간: 0.00초)
# 페이지 82/342 처리 완료 (소요 시간: 0.00초)
# 페이지 83/342 처리 완료 (소요 시간: 0.00초)
# 페이지 84/342 처리 완료 (소요 시간: 0.00초)
# 페이지 85/342 처리 완료 (소요 시간: 0.00초)
# 페이지 86/342 처리 완료 (소요 시간: 0.00초)
# 페이지 87/342 처리 완료 (소요 시간: 0.00초)
# 페이지 88/342 처리 완료 (소요 시간: 0.00초)
# 페이지 89/342 처리 완료 (소요 시간: 0.00초)
# 페이지 90/342 처리 완료 (소요 시간: 0.00초)
# 페이지 91/342 처리 완료 (소요 시간: 0.00초)
# 페이지 92/342 처리 완료 (소요 시간: 0.00초)
# 페이지 93/342 처리 완료 (소요 시간: 0.00초)
# 페이지 94/342 처리 완료 (소요 시간: 0.00초)
# 페이지 95/342 처리 완료 (소요 시간: 0.00초)
# 페이지 96/342 처리 완료 (소요 시간: 0.00초)
# 페이지 97/342 처리 완료 (소요 시간: 0.00초)
# 페이지 98/342 처리 완료 (소요 시간: 0.00초)
# 페이지 99/342 처리 완료 (소요 시간: 0.00초)
# 분할 PDF 2 처리 완료 (소요 시간: 21.01초)
#
# 처리 중인 분할 PDF 3
# API 요청 제출 중...
# 결과 대기 중...
# ..
# 결과 다운로드 및 처리 중...
# 페이지 100/342 처리 완료 (소요 시간: 0.00초)
# 페이지 101/342 처리 완료 (소요 시간: 0.00초)
# 페이지 102/342 처리 완료 (소요 시간: 0.00초)
# 페이지 103/342 처리 완료 (소요 시간: 0.00초)
# 페이지 104/342 처리 완료 (소요 시간: 0.00초)
# 페이지 105/342 처리 완료 (소요 시간: 0.00초)
# 페이지 106/342 처리 완료 (소요 시간: 0.00초)
# 페이지 107/342 처리 완료 (소요 시간: 0.00초)
# 페이지 108/342 처리 완료 (소요 시간: 0.00초)
# 페이지 109/342 처리 완료 (소요 시간: 0.00초)
# 페이지 110/342 처리 완료 (소요 시간: 0.00초)
# 페이지 111/342 처리 완료 (소요 시간: 0.00초)
# 페이지 112/342 처리 완료 (소요 시간: 0.00초)
# 페이지 113/342 처리 완료 (소요 시간: 0.00초)
# 페이지 114/342 처리 완료 (소요 시간: 0.00초)
# 페이지 115/342 처리 완료 (소요 시간: 0.00초)
# 페이지 116/342 처리 완료 (소요 시간: 0.00초)
# 페이지 117/342 처리 완료 (소요 시간: 0.00초)
# 페이지 118/342 처리 완료 (소요 시간: 0.00초)
# 페이지 119/342 처리 완료 (소요 시간: 0.00초)
# 페이지 120/342 처리 완료 (소요 시간: 0.00초)
# 페이지 121/342 처리 완료 (소요 시간: 0.00초)
# 페이지 122/342 처리 완료 (소요 시간: 0.00초)
# 페이지 123/342 처리 완료 (소요 시간: 0.00초)
# 페이지 124/342 처리 완료 (소요 시간: 0.00초)
# 페이지 125/342 처리 완료 (소요 시간: 0.00초)
# 페이지 126/342 처리 완료 (소요 시간: 0.00초)
# 페이지 127/342 처리 완료 (소요 시간: 0.00초)
# 페이지 128/342 처리 완료 (소요 시간: 0.00초)
# 페이지 129/342 처리 완료 (소요 시간: 0.00초)
# 페이지 130/342 처리 완료 (소요 시간: 0.00초)
# 페이지 131/342 처리 완료 (소요 시간: 0.00초)
# 페이지 132/342 처리 완료 (소요 시간: 0.00초)
# 페이지 133/342 처리 완료 (소요 시간: 0.00초)
# 페이지 134/342 처리 완료 (소요 시간: 0.00초)
# 페이지 135/342 처리 완료 (소요 시간: 0.00초)
# 페이지 136/342 처리 완료 (소요 시간: 0.00초)
# 페이지 137/342 처리 완료 (소요 시간: 0.00초)
# 페이지 138/342 처리 완료 (소요 시간: 0.00초)
# 페이지 139/342 처리 완료 (소요 시간: 0.00초)
# 페이지 140/342 처리 완료 (소요 시간: 0.00초)
# 페이지 141/342 처리 완료 (소요 시간: 0.00초)
# 페이지 142/342 처리 완료 (소요 시간: 0.00초)
# 페이지 143/342 처리 완료 (소요 시간: 0.00초)
# 페이지 144/342 처리 완료 (소요 시간: 0.00초)
# 페이지 145/342 처리 완료 (소요 시간: 0.00초)
# 페이지 146/342 처리 완료 (소요 시간: 0.00초)
# 페이지 147/342 처리 완료 (소요 시간: 0.00초)
# 페이지 148/342 처리 완료 (소요 시간: 0.00초)
# 분할 PDF 3 처리 완료 (소요 시간: 21.04초)
#
# 처리 중인 분할 PDF 4
# API 요청 제출 중...
# 결과 대기 중...
# ..
# 결과 다운로드 및 처리 중...
# 페이지 149/342 처리 완료 (소요 시간: 0.00초)
# 페이지 150/342 처리 완료 (소요 시간: 0.00초)
# 페이지 151/342 처리 완료 (소요 시간: 0.00초)
# 페이지 152/342 처리 완료 (소요 시간: 0.00초)
# 페이지 153/342 처리 완료 (소요 시간: 0.00초)
# 페이지 154/342 처리 완료 (소요 시간: 0.00초)
# 페이지 155/342 처리 완료 (소요 시간: 0.00초)
# 페이지 156/342 처리 완료 (소요 시간: 0.00초)
# 페이지 157/342 처리 완료 (소요 시간: 0.00초)
# 페이지 158/342 처리 완료 (소요 시간: 0.00초)
# 페이지 159/342 처리 완료 (소요 시간: 0.00초)
# 페이지 160/342 처리 완료 (소요 시간: 0.00초)
# 페이지 161/342 처리 완료 (소요 시간: 0.00초)
# 페이지 162/342 처리 완료 (소요 시간: 0.00초)
# 페이지 163/342 처리 완료 (소요 시간: 0.00초)
# 페이지 164/342 처리 완료 (소요 시간: 0.00초)
# 페이지 165/342 처리 완료 (소요 시간: 0.00초)
# 페이지 166/342 처리 완료 (소요 시간: 0.00초)
# 페이지 167/342 처리 완료 (소요 시간: 0.00초)
# 페이지 168/342 처리 완료 (소요 시간: 0.00초)
# 페이지 169/342 처리 완료 (소요 시간: 0.00초)
# 페이지 170/342 처리 완료 (소요 시간: 0.00초)
# 페이지 171/342 처리 완료 (소요 시간: 0.00초)
# 페이지 172/342 처리 완료 (소요 시간: 0.00초)
# 페이지 173/342 처리 완료 (소요 시간: 0.00초)
# 페이지 174/342 처리 완료 (소요 시간: 0.00초)
# 페이지 175/342 처리 완료 (소요 시간: 0.00초)
# 페이지 176/342 처리 완료 (소요 시간: 0.00초)
# 페이지 177/342 처리 완료 (소요 시간: 0.00초)
# 페이지 178/342 처리 완료 (소요 시간: 0.00초)
# 페이지 179/342 처리 완료 (소요 시간: 0.00초)
# 페이지 180/342 처리 완료 (소요 시간: 0.00초)
# 페이지 181/342 처리 완료 (소요 시간: 0.00초)
# 페이지 182/342 처리 완료 (소요 시간: 0.00초)
# 페이지 183/342 처리 완료 (소요 시간: 0.00초)
# 페이지 184/342 처리 완료 (소요 시간: 0.00초)
# 페이지 185/342 처리 완료 (소요 시간: 0.00초)
# 페이지 186/342 처리 완료 (소요 시간: 0.00초)
# 페이지 187/342 처리 완료 (소요 시간: 0.00초)
# 페이지 188/342 처리 완료 (소요 시간: 0.00초)
# 페이지 189/342 처리 완료 (소요 시간: 0.00초)
# 페이지 190/342 처리 완료 (소요 시간: 0.00초)
# 페이지 191/342 처리 완료 (소요 시간: 0.00초)
# 페이지 192/342 처리 완료 (소요 시간: 0.00초)
# 페이지 193/342 처리 완료 (소요 시간: 0.00초)
# 페이지 194/342 처리 완료 (소요 시간: 0.00초)
# 페이지 195/342 처리 완료 (소요 시간: 0.00초)
# 페이지 196/342 처리 완료 (소요 시간: 0.00초)
# 분할 PDF 4 처리 완료 (소요 시간: 21.04초)
#
# 처리 중인 분할 PDF 5
# API 요청 제출 중...
# 결과 대기 중...
# ..
# 결과 다운로드 및 처리 중...
# 페이지 197/342 처리 완료 (소요 시간: 0.00초)
# 페이지 198/342 처리 완료 (소요 시간: 0.00초)
# 페이지 199/342 처리 완료 (소요 시간: 0.00초)
# 페이지 200/342 처리 완료 (소요 시간: 0.00초)
# 페이지 201/342 처리 완료 (소요 시간: 0.00초)
# 페이지 202/342 처리 완료 (소요 시간: 0.00초)
# 페이지 203/342 처리 완료 (소요 시간: 0.00초)
# 페이지 204/342 처리 완료 (소요 시간: 0.00초)
# 페이지 205/342 처리 완료 (소요 시간: 0.00초)
# 페이지 206/342 처리 완료 (소요 시간: 0.00초)
# 페이지 207/342 처리 완료 (소요 시간: 0.00초)
# 페이지 208/342 처리 완료 (소요 시간: 0.00초)
# 페이지 209/342 처리 완료 (소요 시간: 0.00초)
# 페이지 210/342 처리 완료 (소요 시간: 0.00초)
# 페이지 211/342 처리 완료 (소요 시간: 0.00초)
# 페이지 212/342 처리 완료 (소요 시간: 0.00초)
# 페이지 213/342 처리 완료 (소요 시간: 0.00초)
# 페이지 214/342 처리 완료 (소요 시간: 0.00초)
# 페이지 215/342 처리 완료 (소요 시간: 0.00초)
# 페이지 216/342 처리 완료 (소요 시간: 0.00초)
# 페이지 217/342 처리 완료 (소요 시간: 0.00초)
# 페이지 218/342 처리 완료 (소요 시간: 0.00초)
# 페이지 219/342 처리 완료 (소요 시간: 0.00초)
# 페이지 220/342 처리 완료 (소요 시간: 0.00초)
# 페이지 221/342 처리 완료 (소요 시간: 0.00초)
# 페이지 222/342 처리 완료 (소요 시간: 0.00초)
# 페이지 223/342 처리 완료 (소요 시간: 0.00초)
# 페이지 224/342 처리 완료 (소요 시간: 0.00초)
# 페이지 225/342 처리 완료 (소요 시간: 0.00초)
# 페이지 226/342 처리 완료 (소요 시간: 0.00초)
# 페이지 227/342 처리 완료 (소요 시간: 0.00초)
# 페이지 228/342 처리 완료 (소요 시간: 0.00초)
# 페이지 229/342 처리 완료 (소요 시간: 0.00초)
# 페이지 230/342 처리 완료 (소요 시간: 0.00초)
# 페이지 231/342 처리 완료 (소요 시간: 0.00초)
# 페이지 232/342 처리 완료 (소요 시간: 0.00초)
# 페이지 233/342 처리 완료 (소요 시간: 0.00초)
# 페이지 234/342 처리 완료 (소요 시간: 0.00초)
# 페이지 235/342 처리 완료 (소요 시간: 0.00초)
# 페이지 236/342 처리 완료 (소요 시간: 0.00초)
# 페이지 237/342 처리 완료 (소요 시간: 0.00초)
# 페이지 238/342 처리 완료 (소요 시간: 0.00초)
# 페이지 239/342 처리 완료 (소요 시간: 0.00초)
# 페이지 240/342 처리 완료 (소요 시간: 0.00초)
# 페이지 241/342 처리 완료 (소요 시간: 0.00초)
# 페이지 242/342 처리 완료 (소요 시간: 0.00초)
# 페이지 243/342 처리 완료 (소요 시간: 0.00초)
# 분할 PDF 5 처리 완료 (소요 시간: 21.07초)
#
# 처리 중인 분할 PDF 6
# API 요청 제출 중...
# 결과 대기 중...
# ..
# 결과 다운로드 및 처리 중...
# 페이지 244/342 처리 완료 (소요 시간: 0.00초)
# 페이지 245/342 처리 완료 (소요 시간: 0.00초)
# 페이지 246/342 처리 완료 (소요 시간: 0.00초)
# 페이지 247/342 처리 완료 (소요 시간: 0.00초)
# 페이지 248/342 처리 완료 (소요 시간: 0.00초)
# 페이지 249/342 처리 완료 (소요 시간: 0.00초)
# 페이지 250/342 처리 완료 (소요 시간: 0.00초)
# 페이지 251/342 처리 완료 (소요 시간: 0.00초)
# 페이지 252/342 처리 완료 (소요 시간: 0.00초)
# 페이지 253/342 처리 완료 (소요 시간: 0.00초)
# 페이지 254/342 처리 완료 (소요 시간: 0.00초)
# 페이지 255/342 처리 완료 (소요 시간: 0.00초)
# 페이지 256/342 처리 완료 (소요 시간: 0.00초)
# 페이지 257/342 처리 완료 (소요 시간: 0.00초)
# 페이지 258/342 처리 완료 (소요 시간: 0.00초)
# 페이지 259/342 처리 완료 (소요 시간: 0.00초)
# 페이지 260/342 처리 완료 (소요 시간: 0.00초)
# 페이지 261/342 처리 완료 (소요 시간: 0.00초)
# 페이지 262/342 처리 완료 (소요 시간: 0.00초)
# 페이지 263/342 처리 완료 (소요 시간: 0.00초)
# 페이지 264/342 처리 완료 (소요 시간: 0.00초)
# 페이지 265/342 처리 완료 (소요 시간: 0.00초)
# 페이지 266/342 처리 완료 (소요 시간: 0.00초)
# 페이지 267/342 처리 완료 (소요 시간: 0.00초)
# 페이지 268/342 처리 완료 (소요 시간: 0.00초)
# 페이지 269/342 처리 완료 (소요 시간: 0.00초)
# 페이지 270/342 처리 완료 (소요 시간: 0.00초)
# 페이지 271/342 처리 완료 (소요 시간: 0.00초)
# 페이지 272/342 처리 완료 (소요 시간: 0.00초)
# 페이지 273/342 처리 완료 (소요 시간: 0.00초)
# 페이지 274/342 처리 완료 (소요 시간: 0.00초)
# 페이지 275/342 처리 완료 (소요 시간: 0.00초)
# 페이지 276/342 처리 완료 (소요 시간: 0.00초)
# 페이지 277/342 처리 완료 (소요 시간: 0.00초)
# 페이지 278/342 처리 완료 (소요 시간: 0.00초)
# 페이지 279/342 처리 완료 (소요 시간: 0.00초)
# 페이지 280/342 처리 완료 (소요 시간: 0.00초)
# 페이지 281/342 처리 완료 (소요 시간: 0.00초)
# 페이지 282/342 처리 완료 (소요 시간: 0.00초)
# 페이지 283/342 처리 완료 (소요 시간: 0.00초)
# 페이지 284/342 처리 완료 (소요 시간: 0.00초)
# 페이지 285/342 처리 완료 (소요 시간: 0.00초)
# 페이지 286/342 처리 완료 (소요 시간: 0.00초)
# 페이지 287/342 처리 완료 (소요 시간: 0.00초)
# 페이지 288/342 처리 완료 (소요 시간: 0.00초)
# 페이지 289/342 처리 완료 (소요 시간: 0.00초)
# 페이지 290/342 처리 완료 (소요 시간: 0.00초)
# 페이지 291/342 처리 완료 (소요 시간: 0.00초)
# 분할 PDF 6 처리 완료 (소요 시간: 21.15초)
#
# 처리 중인 분할 PDF 7
# API 요청 제출 중...
# 결과 대기 중...
# ..
# 결과 다운로드 및 처리 중...
# 페이지 292/342 처리 완료 (소요 시간: 0.00초)
# 페이지 293/342 처리 완료 (소요 시간: 0.00초)
# 페이지 294/342 처리 완료 (소요 시간: 0.00초)
# 페이지 295/342 처리 완료 (소요 시간: 0.00초)
# 페이지 296/342 처리 완료 (소요 시간: 0.00초)
# 페이지 297/342 처리 완료 (소요 시간: 0.00초)
# 페이지 298/342 처리 완료 (소요 시간: 0.00초)
# 페이지 299/342 처리 완료 (소요 시간: 0.00초)
# 페이지 300/342 처리 완료 (소요 시간: 0.00초)
# 페이지 301/342 처리 완료 (소요 시간: 0.00초)
# 페이지 302/342 처리 완료 (소요 시간: 0.00초)
# 페이지 303/342 처리 완료 (소요 시간: 0.00초)
# 페이지 304/342 처리 완료 (소요 시간: 0.00초)
# 페이지 305/342 처리 완료 (소요 시간: 0.00초)
# 페이지 306/342 처리 완료 (소요 시간: 0.00초)
# 페이지 307/342 처리 완료 (소요 시간: 0.00초)
# 페이지 308/342 처리 완료 (소요 시간: 0.00초)
# 페이지 309/342 처리 완료 (소요 시간: 0.00초)
# 페이지 310/342 처리 완료 (소요 시간: 0.00초)
# 페이지 311/342 처리 완료 (소요 시간: 0.00초)
# 페이지 312/342 처리 완료 (소요 시간: 0.00초)
# 페이지 313/342 처리 완료 (소요 시간: 0.00초)
# 페이지 314/342 처리 완료 (소요 시간: 0.00초)
# 페이지 315/342 처리 완료 (소요 시간: 0.00초)
# 페이지 316/342 처리 완료 (소요 시간: 0.00초)
# 페이지 317/342 처리 완료 (소요 시간: 0.00초)
# 페이지 318/342 처리 완료 (소요 시간: 0.00초)
# 페이지 319/342 처리 완료 (소요 시간: 0.00초)
# 페이지 320/342 처리 완료 (소요 시간: 0.00초)
# 페이지 321/342 처리 완료 (소요 시간: 0.00초)
# 페이지 322/342 처리 완료 (소요 시간: 0.00초)
# 페이지 323/342 처리 완료 (소요 시간: 0.00초)
# 페이지 324/342 처리 완료 (소요 시간: 0.00초)
# 페이지 325/342 처리 완료 (소요 시간: 0.00초)
# 페이지 326/342 처리 완료 (소요 시간: 0.00초)
# 분할 PDF 7 처리 완료 (소요 시간: 21.00초)
#
# 텍스트 추출 완료
# 총 소요 시간: 147.54초
# 평균 페이지 처리 시간: 0.00초
#
# 추출된 텍스트가 다음 위치에 저장되었습니다: raw_docs/상품3/판매약관_신한(간편가입)든든한실속종신보험(무배당, 보증비용부과형)[해약환급금 미지급형]_240903_extracted.txt
# 추출된 텍스트 (처음 500자):
# 약관
# 신한(간편가입)
# 든든한실속종신보험
# (무배당, 보증비용부과형)
# [해약환급금 미지급형]
# 신한라이프
#
# --- End of Page 1 ---
#
# 고객에게 드리는 감사의 인사말씀
# 먼저, 변함없는 신뢰와 성원을 보내주신 고객여러분께
# 진심으로 깊은 감사의 말씀을 드립니다.
# 2021년 7월 새롭게 태어난 신한라이프는
# 대한민국 생명보험업계를 선도하는 一流 리딩 컴퍼니를 지향합니다.
# 신한라이프는 'NewLife, Life에 새로운 가치를 더하다' 라는
# 비전을 가지고 있습니다.
# 생명보험업계 최고 수준의 재무건전성을 유지하고,
# 고객을 이롭게 하는 새로운 보험상품을 개발하고
# 모바일 기반의 디지털 전환과 헬스케어 서비스 확대를 통하여
# '고객님의 삶에 새로운 가치를 더하는' 신한라이프가 되겠습니다.
# 나아가 '금융으로 세상을 이롭게 한다'는 회사의 미션을 실천하고
# 나눔과 상생으로 소외된 이웃에게 힘이 되며,
# ESG(환경사회지배구조: Environment,Social,Governance) 중심 경영을 통해
# ...
